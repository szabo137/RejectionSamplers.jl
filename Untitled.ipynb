# %%
import Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/Work/jlProjects/QEDjl-project/forks/RejectionSamplers.jl`

# %%
using BenchmarkTools

# %%
# Define a parent BenchmarkGroup to contain our suite
suite = BenchmarkGroup()

# Add some child groups to our benchmark suite. The most relevant BenchmarkGroup constructor
# for this case is BenchmarkGroup(tags::Vector). These tags are useful for
# filtering benchmarks by topic, which we'll cover in a later section.
suite["utf8"] = BenchmarkGroup(["string", "unicode"])
suite["trig"] = BenchmarkGroup(["math", "triangles"])

# Add some benchmarks to the "utf8" group
teststr = join(rand('a':'d', 10^4));
suite["utf8"]["replace"] = @benchmarkable replace($teststr, "a" => "b")
suite["utf8"]["join"] = @benchmarkable join($teststr, $teststr)

# Add some benchmarks to the "trig" group
for f in (sin, cos, tan)
    for x in (0.0, pi)
        suite["trig"][string(f), x] = @benchmarkable $(f)($x)
    end
end

# %%
suite
# Out:
# 2-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "utf8" => 2-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["string", "unicode"]
# 	  "join" => Benchmark(evals=1, seconds=5.0, samples=10000)
# 	  "replace" => Benchmark(evals=1, seconds=5.0, samples=10000)
#   "trig" => 6-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["math", "triangles"]
# 	  ("sin", "π") => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("cos", 0.0) => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("tan", "π") => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("tan", 0.0) => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("sin", 0.0) => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("cos", "π") => Benchmark(evals=1000, seconds=5.0, samples=10000)

# %%
run(suite, verbose=true)
# Out:
# (1/2) benchmarking "utf8"...
#   (1/2) benchmarking "join"...
#   done (took 5.5416175 seconds)
#   (2/2) benchmarking "replace"...
#   done (took 1.344188375 seconds)
# done (took 7.248110667 seconds)
# (2/2) benchmarking "trig"...
#   (1/6) benchmarking ("sin", "π")...
#   done (took 0.009168167 seconds)
#   (2/6) benchmarking ("cos", 0.0)...
#   done (took 0.009137833 seconds)
#   (3/6) benchmarking ("tan", "π")...
#   done (took 0.000824542 seconds)
#   (4/6) benchmarking ("tan", 0.0)...
#   done (took 0.000850166 seconds)
#   (5/6) benchmarking ("sin", 0.0)...
#   done (took 0.000824 seconds)
#   (6/6) benchmarking ("cos", "π")...
#   done (took 0.000823542 seconds)
# done (took 0.370311458 seconds)
# 2-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "utf8" => 2-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["string", "unicode"]
# 	  "join" => Trial(19.307 ms)
# 	  "replace" => Trial(96.292 μs)
#   "trig" => 6-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["math", "triangles"]
# 	  ("sin", "π") => Trial(0.001 ns)
# 	  ("cos", 0.0) => Trial(0.001 ns)
# 	  ("tan", "π") => Trial(0.001 ns)
# 	  ("tan", 0.0) => Trial(0.001 ns)
# 	  ("sin", 0.0) => Trial(0.001 ns)
# 	  ("cos", "π") => Trial(0.001 ns)

# %%
tune!(suite)
# Out:
# 2-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "utf8" => 2-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["string", "unicode"]
# 	  "join" => Benchmark(evals=1, seconds=5.0, samples=10000)
# 	  "replace" => Benchmark(evals=1, seconds=5.0, samples=10000)
#   "trig" => 6-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["math", "triangles"]
# 	  ("sin", "π") => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("cos", 0.0) => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("tan", "π") => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("tan", 0.0) => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("sin", 0.0) => Benchmark(evals=1000, seconds=5.0, samples=10000)
# 	  ("cos", "π") => Benchmark(evals=1000, seconds=5.0, samples=10000)

# %%
results = run(suite; verbose = true)
# Out:
# (1/2) benchmarking "utf8"...
#   (1/2) benchmarking "join"...
#   done (took 5.74945325 seconds)
#   (2/2) benchmarking "replace"...
#   done (took 1.333390084 seconds)
# done (took 7.448200625 seconds)
# (2/2) benchmarking "trig"...
#   (1/6) benchmarking ("sin", "π")...
#   done (took 0.01779975 seconds)
#   (2/6) benchmarking ("cos", 0.0)...
#   done (took 0.052052 seconds)
#   (3/6) benchmarking ("tan", "π")...
#   done (took 0.017948417 seconds)
#   (4/6) benchmarking ("tan", 0.0)...
#   done (took 0.050255667 seconds)
#   (5/6) benchmarking ("sin", 0.0)...
#   done (took 0.050612959 seconds)
#   (6/6) benchmarking ("cos", "π")...
#   done (took 0.01762175 seconds)
# done (took 0.567709583 seconds)
# 2-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "utf8" => 2-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["string", "unicode"]
# 	  "join" => Trial(19.349 ms)
# 	  "replace" => Trial(96.250 μs)
#   "trig" => 6-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["math", "triangles"]
# 	  ("sin", "π") => Trial(1.542 ns)
# 	  ("cos", 0.0) => Trial(4.792 ns)
# 	  ("tan", "π") => Trial(1.542 ns)
# 	  ("tan", 0.0) => Trial(4.792 ns)
# 	  ("sin", 0.0) => Trial(4.792 ns)
# 	  ("cos", "π") => Trial(1.583 ns)

# %%
m(results)
# Out:
# 2-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "utf8" => 2-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["string", "unicode"]
# 	  "join" => 1.93495e7
# 	  "replace" => 96250.0
#   "trig" => 6-element BenchmarkTools.BenchmarkGroup:
# 	  tags: ["math", "triangles"]
# 	  ("sin", "π") => 1.542
# 	  ("cos", 0.0) => 4.792
# 	  ("tan", "π") => 1.542
# 	  ("tan", 0.0) => 4.792
# 	  ("sin", 0.0) => 4.792
# 	  ("cos", "π") => 1.583
